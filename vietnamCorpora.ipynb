# %%
# some essentials

import pandas
import os
from os import listdir
from os.path import isfile, join
import re
import lucem_illud
import nltk


# original article regex = r'(DOCUMENTS)(.*?)(The New York Times Company)'
# original date regex = r'^(DOCUMENTS)(.*?)(,)(Monday|Tuesday|Wednesday|Thursday|Friday|Saturday|Sunday)$'

# %%
# from my personal machine
targetDir = "C:/Users/Alex/contentAnalysis/vietnam/data/NYT"

# %%
# helper functions for getting article text and article date

def getText(x):
    reResults = re.findall(r'(DOCUMENTS)(.*?)(The New York Times Company)', x.replace('\n', ' '), flags = re.M)
    return[t[1] for t in reResults]

def getDate(x) :
    reResults = re.findall(r'(DOCUMENTS)(.*?)(Monday|Tuesday|Wednesday|Thursday|Friday|Saturday|Sunday)', x.replace('\n', ' '))
    return[t[1] for t in reResults]

# %%
# Below, I make multiple runs at cleaning.
# First run: Get everything into a dataframe by date and article text

nytText = []
nytDate = []


for file in (file for file in os.scandir(targetDir) if file.is_file() and not file.name.startswith('.')):
    with open(file.path, encoding='utf-8') as f:
        workingText = f.read()
        workingText = str(workingText)
        goodText = getText(workingText)
        date = getDate(workingText)
        nytText += goodText
        nytDate += date
        
        
# for some reason I get one more date than I should. Should probably figure out why at some point.
# NB - 25825 might be the problem row - seems to still have full date attached
nytDF = pandas.DataFrame({'date' : nytDate[:-1], 'article' : nytText})

# %%
# some helper functions for my second run - these are made ad hoc, so... 
# probably will not be useful as-is for other text cleaning projects


# strip out NYT title upper case
def cleanerUpper(x):
    return re.sub(r'\s+NEW YORK TIMES\s+', '', x)

# strip out NYT title lower case
def cleanerLower(x):
    return re.sub(r'\s+The New York Times\s+', '', x)

#strip out useless text
def cleanerText(x):
    return re.sub(r'(January|February|March|April|May|June|July|August|September|October|November|December)(.*?)(LENGTH:)', '', x)

# strip out copyright and year
def cleanerCopy(x):
    return re.sub(r'(Copyright)\s+(\d{4})', '', x)

# simplify the date
def cleanerYear(x):
    return re.sub(r'(\D+)\s(\d{1,2})\W', '', x)

# behaves as advertised - destroys first comma found
def destroyComma(x):
    return re.sub(r',', '', x)

# strip word count
def cleanWordCount(x):
    return re.sub(r'(\d+).(words)', '', x)

# death to datelines
# not that clean. What does 25835 look like before this function?
def cleanDateline(x):
    return re.sub(r'(DATELINE:)\s(\w+)(,\s(\w+).\s(\d+))?', '', x)

# %%
# second run at cleaning - clean up article and date columns

# clean dates
nytDF['date'] = nytDF['date'].apply(cleanerUpper)
nytDF['date'] = nytDF['date'].apply(cleanerLower)
#nytDF['date'] = nytDF['date'].apply(cleanerYear)
nytDF['date'] = nytDF['date'].apply(destroyComma)

#clean articles
nytDF['article'] = nytDF['article'].apply(cleanerUpper)
nytDF['article'] = nytDF['article'].apply(cleanerLower)
nytDF['article'] = nytDF['article'].apply(cleanerText)
nytDF['article'] = nytDF['article'].apply(cleanerCopy)
nytDF['article'] = nytDF['article'].apply(cleanWordCount)
nytDF['article'] = nytDF['article'].apply(cleanDateline)

# %%
print(nytDF)
# Out:
#                                                  article                date
# 0         S Vietnamese House of Reprs, by narrow majo...     January 1 1970
# 1         US rept (as of Dec 20, 1969) of 9 yrs of Vi...     January 1 1970
# 25843        For 27 years, the authority that operate...  September 24 1995
# 25844        The Jewish New Year begins tonight, but ...  September 24 1995
# 25845      WITH the wisdom that hindsight affords, Ri...  September 24 1995
# 25846       HUDDLE FEVER Living in the Immigrant City...  September 24 1995
# 25847        To keep peace with important allies, Def...  September 24 1995
# 25848      A New Jersey businessman implicated on vid...  September 27 1995
# 25849        Foreign policy came calling at the White...  September 28 1995
# 25850      The 33d New York Film Festival opens tonig...  September 29 1995
# 25851      There is a reason the terms "sophomoric" a...  September 29 1995
#
# [25852 rows x 2 columns]

# %%
# that's a pretty big corpus - this one is more manageable. 
# filtered for every article 1980-1989 - about ~11k

nyt80s = nytDF[nytDF['date'].str.contains('198\d', na = False)]
nyt80sClean = nyt80s

# also tokenize and normalize
nyt80sClean['tokenizedArticle'] = nyt80sClean['article'].apply(lambda x: nltk.word_tokenize(x))
nyt80sClean['normalizedArticle'] = nyt80sClean['tokenizedArticle'].apply(lambda x: lucem_illud.normalizeTokens(x, stopwordLst = lucem_illud.stop_words_basic, stemmer = lucem_illud.stemmer_basic))
# Out:
# D:\computation\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\computation\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
print(nyt80sClean)
# Out:
#                                                  article                date  \
# 7369      '79 food production in Vietnam was only 13....     January 2 1980
# 7370      Karleton Armstrong, convicted of '70 bombin...     January 2 1980
# 7371      Militants holding US diplomatic personnel h...     January 5 1980
# 7372      Militants holding US diplomatic personnel h...     January 5 1980
# 7373      China apparently concludes that best strate...     January 5 1980
# 7374      5 US chemical companies that produced milit...     January 7 1980
# 7375      Phnom Penh, Cambodia, celebrates 1st annive...     January 8 1980
# 7376      Australian Government agrees to form indepe...     January 8 1980
# 7377      Warrant Officer Francis Anton, former Army ...     January 9 1980
# 7378      Author Richard J Walton article on Soviet i...    January 10 1980
# 7379      Former Vietnam war prisoner Luis Antonio Or...    January 10 1980
# 7380      Vietnam accuses China of conducting large-s...    January 10 1980
# 7381      Military prosecutors, in surprise move, fin...    January 12 1980
# 7382      Vietnam accuses US and China of military al...    January 14 1980
# 7383      Neil Sheehan interview with Tran Ngoc Chau,...    January 14 1980
# 7384      Talat Sait Halman article on prevalent myth...    January 15 1980
# 7385      Yuri Tavrovsky letter disputes December 19 ...    January 15 1980
# 7386      Pakistan Pres Mohammed Zia ul-Haq, commenti...    January 18 1980
# 7387      China accuses Vietnam of killing at least 4...    January 18 1980
# 7388      Pakistani Pres Mohammed Zia ul-Haq, intervi...    January 18 1980
# 7389      Prof John Somerville letter likens US 'hyst...    January 24 1980
# 7390      Article on history of Selective Service Sys...    January 24 1980
# 7391      Senate approves 15% increase in educational...    January 25 1980
# 7392      ILO announces membership of Vietnam in orga...    January 26 1980
# 7393      Letter by Kay Camp (Women's International L...    January 27 1980
# 7394      Chinese Foreign Ministry says its chief neg...    January 29 1980
# 7395      China issues document reasserting claim to ...    January 31 1980
# 7396      Defense witness Staff Sgt John E Peterson, ...    February 1 1980
# 7397      Karleton Armstrong is released on Federal p...    February 1 1980
# 7398      Military judge Major Thomas B Hamilton Jr r...    February 2 1980
# ...                                                  ...                 ...
# 18540      Wanted: a new public enemy. Height, weight...  September 24 1989
# 7377   [warrant, offic, franci, anton, former, armi, ...
# 7378   [author, richard, j, walton, articl, soviet, i...
# 7379   [former, vietnam, war, prison, lui, antonio, s...
# 7380   [vietnam, accus, china, conduct, militari, exe...
# 7381   [militari, prosecutor, surpris, move, finish, ...
# 7382   [vietnam, accus, us, china, militari, allianc,...
# 7383   [neil, sheehan, interview, tran, ngoc, chau, f...
# 7384   [talat, sait, halman, articl, preval, myth, re...
# 7385   [yuri, tavrovski, letter, disput, decemb, edit...
# 7386   [pakistan, pres, moham, zia, comment, soviet, ...
# 7387   [china, accus, vietnam, kill, least, chines, a...
# 7388   [pakistani, pres, moham, zia, interview, sever...
# 7389   [prof, john, somervill, letter, liken, us, afg...
# 7390   [articl, histori, select, servic, system, draf...
# 7391   [senat, approv, increas, educ, benefit, millio...
# 7392   [ilo, announc, membership, vietnam, organ, lan...
# 7393   [letter, kay, camp, women, intern, leagu, hold...
# 7394   [chines, foreign, ministri, say, chief, negoti...
# 7395   [china, issu, document, reassert, claim, parac...
# 7396   [defens, wit, staff, sgt, john, e, peterson, h...
# 7397   [karleton, armstrong, releas, feder, parol, fo...
# 7398   [militari, judg, major, thoma, b, hamilton, jr...
# ...                                                  ...
# 18540  [want, new, public, enemi, height, weight, sex...
# 18541  [cold, hbo, laser, disk, close, caption, hour,...
# 18542  [shanghai, chiang, kaishek, conduct, bloodi, p...
# 18543  [music, eccentr, attitud, music, industri, alo...
# 18544  [year, ago, young, unknown, japanes, director,...
# 18545  [april, soon, lon, nol, cambodia, presid, fled...
# 18546  [applaus, carol, musk, pp, pittsburgh, univers...
# 18547  [river, ran, backward, william, merritt, unive...
# 18548  [plan, cut, chemic, weapon, arsenal, befor, gl...
# 18549  [headlin, saturday, articl, monitor, vietnames...
# 18550  [penh, cambodia, prime, minist, hun, sen, appe...
# 18551  [fill, confid, born, lifetim, win, faith, repr...
# 18552  [reader, digest, associ, hire, thoma, kenney, ...
# 18553  [chi, minh, citi, vietnam, countri, enjoy, cou...
# 18554  [intern, presid, bush, told, unit, state, dest...
# 18555  [economi, continu, grow, forestal, recess, lea...
# 18556  [bai, vietnam, vietnam, say, last, column, tro...
# 18557  [chi, minh, citi, vietnam, famili, tran, van, ...
# 18558  [vice, presid, dan, quayl, arriv, philippin, t...
# 18559  [vietnames, troop, final, left, cambodia, agre...
# 18560  [sometim, nation, compel, opt, moral, high, gr...
# 18561  [nation, british, foreign, secretari, outlin, ...
# 18562  [intern, canada, becom, money, drug, profit, t...
# 18563  [penh, cambodia, invas, least, repres, foreign...
# 18564  [nation, new, diplomat, struggl, wage, vietnam...
# 18565  [arnold, johnson, member, nation, leadership, ...
# 18566  [bush, administr, told, israel, intend, sell, ...
# 18567  [nation, afghanistan, foreign, minist, told, g...
# 18568  [ferdinand, marco, tough, debonair, came, rule...
# 18569  [mani, way, war, vietnam, relentlessi, visual,...
#
# [11200 rows x 4 columns]

# %%
# save dataframes as csv files 

#nytDF.to_csv('nytFull', index=False, header=True)

#nyt80s.to_csv('nyt80s.csv', index=False, header=True)

nyt80sClean.to_csv('nyt80sClean.csv', index=False, header=True)
